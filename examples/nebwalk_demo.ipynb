# %% [markdown]
# # nebwalk demo
#
# Runnable overview for NEB path setup, optimization, and energy-profile output.

# %%
# %pip install -e .

# %% [markdown]
# ## Morse H3 collinear exchange

# %%
# %run examples/morse_h3.py
from IPython.display import Image, display

display(Image('morse_h3_profile.png'))

# %% [markdown]
# ## Al adatom diffusion with EMT

# %%
# %run examples/al_diffusion_emt.py
display(Image('al_diffusion_profile.png'))

# %% [markdown]
# ## Ethane torsion with Egret-1t
#
# `EGRET_1T.model` must be downloaded separately from rowansci.com and placed in the repository root.

# %%
# %run examples/ethane_egret.py
display(Image('ethane_egret1t_profile.png'))

# %% [markdown]
# ## Validated results
#
# | Example | Calculator | Barrier | Reference | Error |
# |---|---|---:|---:|---:|
# | Morse H3 | Morse analytical | 0.200 eV | 0.193 eV | 4% |
# | Al adatom diffusion | EMT | 0.237 eV | ~0.40 eV | finite-size slab |
# | Ethane C-C torsion | Egret-1t | 0.113 eV | 0.126 eV | 10% |
# | Al vacancy migration | MACE-MP-0 | 0.508 eV | 0.61 eV | 17% |
# | **Mg vacancy HCP** | **MACE-MP-0** | **0.508 eV** | **~0.52 eV** | **2%** |
